# %% [markdown]
# #### Capstone Project II
# #### Case Study : AWS Sales Analyst

# %% [markdown]
# Scenario terkait Dataset :
#
# Studi kasus ini berisi kumpulan data terkait penjualan model bisnis SaaS di Perusahaan AWS (Amazon Web Service). Model bisnis ini sendiri merupakan model bisnis layanan aplikasi perangkat lunak berbasis cloud yang tidak memerlukan perangkat keras lagi. Penyedia layanan telah membuat aplikasi dapat diakses melalui browser oleh pelanggan. Model bisnis yang dijalankan AWS ini memungkinkan mereka memperoleh profit dari penjualan software mereka ke para pelanggan mereka, software yang mereka jual kebanyakan bersifat subscription per bulan.<br>
# Pengertian SaaS atau Software as a Service sendiri adalah suatu aplikasi perangkat lunak yang dapat diakses melalui browser tanpa memerlukan pembelian suatu program atau sistem dan perangkat keras.

# %% [markdown]
# Project Scenario :
#
# Amazon Web Services, Inc. (AWS) adalah anak perusahaan Amazon yang menyediakan platform komputasi awan dan API sesuai permintaan untuk individu, perusahaan, dan pemerintah, dengan basis terukur dan bayar sesuai pemakaian. Layanan web komputasi awan ini menyediakan berbagai layanan terkait jaringan, komputasi, penyimpanan, middleware, IoT, dan kapasitas pemrosesan lainnya, serta alat perangkat lunak melalui server farm AWS.<br>
# Sebagai salah satu perusahaan besar dalam bidang Tech. mereka menyediakan layanan SaaS sebagai salah satu produk mereka. Saat ini para pihak Eksekutif dari AWS ingin mengetahui bagaimana model bisnis mereka berjalan, berdasarkan data historis mereka, mereka ingin mengetahui sejauh mana perusahaan telah berkembang, bagaimana kondisi profit perusahaan pada produk SaaS mereka, dan mereka juga ingin tahu apakah strategi bisnis yang telah diterapkan sudah dapat dikatakan berhasil.

# %% [markdown]
# **ASK :**
#
# Business Task :
#
# Bagaimana perusahaan tetap mendapatkan profit yang tinggi tetapi tetap mendapatkan loyalitas dari pelanggan dan menganalisis pengaruh latar belakang pelanggan pada kebiasaan pembelian mereka dan melakukan penyesuaian pada strategi bisnis perusahaan sesuai data historis penjualan pada pelanggan.
#
# Business Problem :
#
# 1. Apakah besaran diskon yang diberikan mempengaruhi profit.
# 2. Informasi terkait perusahaan pelanggan apakah mempengaruhi profit yang didapatkan oleh perusahaan kita.
# 3. Menganalisis perbedaan latar belakang pelanggan yang mempengaruhi profit pada perusahaan kita.
# 4. Kapankah rentang waktu yang dialami perusahaan kita yang memiliki signifikansi profit.
# 5. Bagaimana rekomendasi strategi sales kita di masa mendatang yang akan memberi profit tinggi pada perusahaan.
#
# Stakeholder :
#
# 1. AWS Executives
# 2. Head of Sales
# 3. Business Managers & Decision Makers
# 4. Sales & Marketing Teams
#
# Ethical Considerations :
#
# - Pastikan privasi data dan anonimisasi, hindari pengungkapan informasi sensitif atau yang dapat diidentifikasi.
# - Mengakui sifat fiktif dari kumpulan data yang digunakan dan menginterpretasikan hasil dengan memahami keterbatasannya.
#
# Expected Outcomes :
#
# Melalui analisis ini, kami bertujuan untuk memberikan wawasan berharga dan rekomendasi yang dapat ditindaklanjuti kepada perusahaan penjualan SaaS fiktif. Temuan ini akan membantu perusahaan mengambil keputusan yang tepat, mengoptimalkan strategi penjualan, dan meningkatkan profitabilitas dalam industri perangkat lunak penjualan dan pemasaran yang kompetitif.
#
# `Note` :
#
# *Karena kumpulan data ini bersifat fiktif, wawasan dan kesimpulan yang diperoleh dari analisis dimaksudkan untuk tujuan pembelajaran dan eksplorasi dalam konteks simulasi lingkungan penjualan SaaS.*

# %% [markdown]
# **Prepare :**
#
# About the Dataset :
#
# Dataset ini berisi data transaksi dari AWS, sebuah perusahaan dengan model bisnis SaaS yang menjual software penjualan dan pemasaran ke perusahaan lain (B2B). Dalam kumpulan data, setiap baris mewakili satu transaksi/pesanan (9,994 transaksi), dan mencakup 19 kolom dengan ukuran data sebesar 1.63 MB.
# Untuk detail pada dataset dimuat pada keterangan berikut :
#
# 1. Row ID : Unique identifier untuk masing-masing transaksi
# 2. Order ID : Unique identifier untuk masing-masing order
# 3. Order Date : Tanggal Pesanan dibuat
# 4. Date Key : Data Numerik yang merepresentasikan tanggal pesanan (Berupa key yang tertera pada software)
# 5. Contact Name : Nama Pemesan (Nama orang yang memesan software)
# 6. Country : Negara asal pelanggan (Tempat Orderan berasal)
# 7. City : Kota asal pelanggan (Tempat Orderan berasal)
# 8. Region : Region asal pelanggan (Tempat Orderan berasal)
# 9. Subregion : Subregion asal pelanggan (Tempat Orderan berasal)
# 10. Customer : Nama Perusahaan yang memesan
# 11. Customer ID : Unique identifier untuk masing-masing pelanggan
# 12. Industry : Industry yang dijalankan oleh perusahaan pelanggan
# 13. Segment : Segmentasi pasar perusahaan pelanggan
# 14. Product : Nama product yang dipesan
# 15. License : Lisensi dari product yang dipesan
# 16. Sales : Total penjualan pada setiap transaksi
# 17. Quantity : Jumlah maksimal User pada sebuah product yang dipesan
# 18. Discount : Potongan harga pada masing-masing transaksi
# 19. Profit : Keuntungan yang didapat perusahaan kita pada setiap transaksi
#
# Data Source :
#
# Data didapat dari database internal perusahaan (AWS) dan disebarluaskan untuk tujuan pembelajaran dan tersedia secara public pada platform Kaggle.com pada link berikut : https://www.kaggle.com/datasets/nnthanh101/aws-saas-sales demi tujuan kepercayaan dan keaslian data maka data ini dilindungi oleh lisensi dan ketentuan yang termuat pada link berikut : https://www.gnu.org/licenses/fdl-1.3.html. Dataset diunduh dalam format .csv.
#
# ROCCC Dataset :
#
# Terkait urusan mengenai bias dan kredibilitas dataset, sumber data yang kami gunakan telah mencapai persyaratan ROCCC:
#
# 1. Reliable and Original of Dataset : Dataset yang digunakan merupakan sebuah dataset publik yang mengandung informasi akurat, detail, lengkap, dan unbiased terkait data penjualan Software pada perusahaan SaaS AWS. Hal ini dapat digunakan untuk mengeksplorasi bagaimana kebiasaan pembelian yang berbeda dari setiap pelanggan.
# 2. Comprehensive and Current of Dataset : Dataset yang digunakan berisi informasi terkait penjualan pada 4 tahun terakhir (2020-2023). Berdasarkan hal ini, maka dapat dikatakan data yang digunakan terkini dan relevan dengan masalah yang akan diselesaikan. Hal ini merupakan salah satu poin penting, dikarenakan nilai kegunaan data akan semakin berkurang seiring berjalannya waktu.
# 3. Cited : Sumber-sumber ini adalah data yang tersedia untuk umum yang disediakan oleh AWS dan Kaggle. Data yang bersumber dari perusahaan besar yang terpercaya dan data publik yang terverifikasi biasanya merupakan sumber data yang baik.

# %% [markdown]
# **Process :**
#
# Tools (Cleaning, Manipulation & Analysis Dataset) :
#
# Language Programming : **Python**, Library : **Pandas & Numpy**
#
# Tools (Visualization) :
#
# **Python** (Library : **Seaborn & Matplotlib.pyplot**) & **Tableau** (Stories)
#
# Dataset : "SaaS_Sales.csv"
#
# Langkah-Langkah Cleaning & Data Manipulation :
#
# 1. Import Dataset
# 2. Cek fungsionalitas masing-masing kolom
# 3. Cek Nilai Null pada seluruh dataset
# 4. Hapus Nilai Null (Jika diperlukan untuk tujuan analisis selanjutnya)
# 5. Cek Tipe data masing-masing nilai pada setiap kolom
# 6. Penambahan kolom baru (jika diperlukan untuk tujuan analisis selanjutnya)
# 7. Cek duplikasi pada dataset
# 8. Pemahaman Data (Descriptive Statistics)
# 9. Handle Outlier (Optional / Tergantung Konteks Data)

# %% [markdown]
# ### **Import Dataset**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('SaaS-Sales.csv')
df.head()
# Out:
#    Row ID          Order ID  Order Date  Date Key    Contact Name  \
# 0       1  EMEA-2022-152156   11/9/2022  20221109     Nathan Bell
# 1       2  EMEA-2022-152156   11/9/2022  20221109     Nathan Bell
# 2       3  AMER-2022-138688   6/13/2022  20220613  Deirdre Bailey
# 3       4  EMEA-2021-108966  10/11/2021  20211011      Zoe Hodges
# 4       5  EMEA-2021-108966  10/11/2021  20211011      Zoe Hodges
#
#          Country           City Region Subregion           Customer  \
# 0        Ireland         Dublin   EMEA      UKIR            Chevron
# 1        Ireland         Dublin   EMEA      UKIR            Chevron
# 2  United States  New York City   AMER     NAMER        Phillips 66
# 3        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
# 4        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
#
#    Customer ID Industry    Segment                 Product     License  \
# 0         1017   Energy        SMB         Marketing Suite  16GRM07R1K
# ...

# %% [markdown]
# ### **Cek Fungsionalitas setiap Kolom**

# %% [markdown]
# Pada kolom Row ID dapat dihapus karena kolom Row ID sudah merepresentasikan masing-masing transaksi, jadi keberadaan kolom Row ID dapat digantikan dengan urutan baris pada masing-masing dataset sehingga kolom ini tidak terlalu dibutuhkan pada tahapan analisis.

# %%
df = df.drop(columns='Row ID')

# %% [markdown]
# ### **Cek Nilai Null**

# %%
df.isna().sum()
# Out:
# Order ID        0
# Order Date      0
# Date Key        0
# Contact Name    0
# Country         0
# City            0
# Region          0
# Subregion       0
# Customer        0
# Customer ID     0
# Industry        0
# Segment         0
# Product         0
# License         0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# Tidak ditemukan Nilai Null pada dataset

# %% [markdown]
# ### **Cek Tipe Data dan Kesesuaiaan Data**

# %% [markdown]
# Penyesuaian Tipe Data dan format tanggal pada kolom Order Date

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      9994 non-null   object
#  1   Order Date    9994 non-null   object
#  2   Date Key      9994 non-null   int64
#  3   Contact Name  9994 non-null   object
#  4   Country       9994 non-null   object
#  5   City          9994 non-null   object
#  6   Region        9994 non-null   object
#  7   Subregion     9994 non-null   object
#  8   Customer      9994 non-null   object
#  9   Customer ID   9994 non-null   int64
#  10  Industry      9994 non-null   object
#  11  Segment       9994 non-null   object
#  12  Product       9994 non-null   object
#  13  License       9994 non-null   object
#  14  Sales         9994 non-null   float64
#  15  Quantity      9994 non-null   int64
#  16  Discount      9994 non-null   float64
#  17  Profit        9994 non-null   float64
# ...

# %% [markdown]
# Pada kolom 'Order Date' data masih bertipe data Object, maka harus diubah menjadi tipe data Datetime

# %% [markdown]
# Mengecek format datetime pada kolom `Order Date`

# %%
from datetime import datetime

def find_date_formats_and_unique_strings(df, column_name):
    date_formats_found = set()
    unique_strings_found = set()
    for value in df[column_name]:
        if pd.notnull(value):
            for date_format in ["%d/%m/%Y", "%m/%d/%Y", "%d/%m/%y", "%m/%d/%y", "%m.%d.%Y", "%m.%d.%y", "%d.%m.%Y", "%d.%m.%y"]:
                try:
                    datetime.strptime(str(value), date_format)
                    date_formats_found.add(date_format)
                    break  
                except ValueError:
                    pass
            else:
                # Jika ditemukan bukan format datetime maka akan ditambahkan pada set unique strings
                unique_strings_found.add(str(value))
    return date_formats_found, unique_strings_found

# %%
def convert_to_ddmmyyyy(value):
    for date_format in ["%d/%m/%Y", "%m/%d/%Y", "%d/%m/%y", "%m/%d/%y", "%m.%d.%Y", "%m.%d.%y", "%d.%m.%Y", "%d.%m.%y"]:
        try:
            date_object = datetime.strptime(str(value), date_format)
            return date_object.strftime(r"%d/%m/%Y")
        except ValueError:
            pass
    return str(value)

# %%
# Find date formats and unique string values present in the 'Date' column of the DataFrame
date_formats, unique_strings = find_date_formats_and_unique_strings(df, 'Order Date')

print("Order Date before formatting:")

print("Date Formats found:")
print(date_formats)

print("\nUnique String Values found:")
print(unique_strings)
# Out:
# Order Date before formatting:
# Date Formats found:
# {'%m/%d/%Y', '%d/%m/%Y'}
#
# Unique String Values found:
# set()

# %% [markdown]
# Ubah format datetime seperti yang diinginkan pada kolom `Order Date`

# %%
df['Order Date'] = df['Order Date'].apply(convert_to_ddmmyyyy)

# %%
df.head()
# Out:
#            Order ID  Order Date  Date Key    Contact Name        Country  \
# 0  EMEA-2022-152156  11/09/2022  20221109     Nathan Bell        Ireland
# 1  EMEA-2022-152156  11/09/2022  20221109     Nathan Bell        Ireland
# 2  AMER-2022-138688  13/06/2022  20220613  Deirdre Bailey  United States
# 3  EMEA-2021-108966  10/11/2021  20211011      Zoe Hodges        Germany
# 4  EMEA-2021-108966  10/11/2021  20211011      Zoe Hodges        Germany
#
#             City Region Subregion           Customer  Customer ID Industry  \
# 0         Dublin   EMEA      UKIR            Chevron         1017   Energy
# 1         Dublin   EMEA      UKIR            Chevron         1017   Energy
# 2  New York City   AMER     NAMER        Phillips 66         1056   Energy
# 3      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell         1031   Energy
# 4      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell         1031   Energy
#
#      Segment                 Product     License     Sales  Quantity  \
# ...

# %%
df['Order Date'].unique()
# Out:
# array(['11/09/2022', '13/06/2022', '10/11/2021', ..., '06/04/2022',
#        '04/12/2021', '22/01/2020'], dtype=object)

# %%
# Find date formats and unique string values present in the 'Date' column of the DataFrame
date_formats, unique_strings = find_date_formats_and_unique_strings(df, 'Order Date')

print("Order Date after formatting:")

print("Date Formats found:")
print(date_formats)

print("\nUnique String Values found:")
print(unique_strings)
# Out:
# Order Date after formatting:
# Date Formats found:
# {'%d/%m/%Y'}
#
# Unique String Values found:
# set()

# %% [markdown]
# Penyesuaiaan Format pada Kolom `Sales` dan `Profit`. Kedua kolom ini diasumsikan dalam format **Puluhan USD$ (Dikali 10$)**. Asumsi ini didasarkan pada harga rata-rata SaaS di Real Life seperti Office 365 For **Bussiness** yang dijual dengan harga minimum di angka **6$**. Asumsi ini diambil karena customer pada data ini adalah nama perusahaan otomatis SaaS yang dijual adalah SaaS for **Bussiness Purpose**

# %%
df['Sales'] = round(df['Sales'] * 10, 2)
df['Profit'] = round(df['Profit'] * 10, 2)

# %% [markdown]
# ### **Penambahan Kolom Baru**

# %% [markdown]
# Menambah kolom 'Year' dan 'Month' pada dataset untuk keperluan analisis selanjutnya

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'],format=r'%d/%m/%Y')

# %%
newColumn = 'Year'
newData = df['Order Date'].dt.year
indexYear = 3
df.insert(indexYear, newColumn, newData)

# %%
newColumnMonth = 'Month'
newDataMonth = df['Order Date'].dt.strftime('%B')
indexMonth = 4
df.insert(indexYear, newColumnMonth, newDataMonth)

# %%
df.head()
# Out:
#            Order ID Order Date  Date Key      Month  Year    Contact Name  \
# 0  EMEA-2022-152156 2022-09-11  20221109  September  2022     Nathan Bell
# 1  EMEA-2022-152156 2022-09-11  20221109  September  2022     Nathan Bell
# 2  AMER-2022-138688 2022-06-13  20220613       June  2022  Deirdre Bailey
# 3  EMEA-2021-108966 2021-11-10  20211011   November  2021      Zoe Hodges
# 4  EMEA-2021-108966 2021-11-10  20211011   November  2021      Zoe Hodges
#
#          Country           City Region Subregion           Customer  \
# 0        Ireland         Dublin   EMEA      UKIR            Chevron
# 1        Ireland         Dublin   EMEA      UKIR            Chevron
# 2  United States  New York City   AMER     NAMER        Phillips 66
# 3        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
# 4        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
#
#    Customer ID Industry    Segment                 Product     License  \
# ...

# %% [markdown]
# Mengecek kembali keseluruhan tipe data dari dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      9994 non-null   object
#  1   Order Date    9994 non-null   datetime64[ns]
#  2   Date Key      9994 non-null   int64
#  3   Month         9994 non-null   object
#  4   Year          9994 non-null   int64
#  5   Contact Name  9994 non-null   object
#  6   Country       9994 non-null   object
#  7   City          9994 non-null   object
#  8   Region        9994 non-null   object
#  9   Subregion     9994 non-null   object
#  10  Customer      9994 non-null   object
#  11  Customer ID   9994 non-null   int64
#  12  Industry      9994 non-null   object
#  13  Segment       9994 non-null   object
#  14  Product       9994 non-null   object
#  15  License       9994 non-null   object
#  16  Sales         9994 non-null   float64
#  17  Quantity      9994 non-null   int64
# ...

# %% [markdown]
# Pada info diatas, kolom `Date Key`, `Year`, dan `Customer ID` dapat diubah menjadi object karena isi value dari ketiga data lebih merepresentasikan object dibanding numerik

# %%
column_to_convert = ['Date Key','Year','Customer ID']

for column in column_to_convert:
    df[column] = df[column].astype('object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      9994 non-null   object
#  1   Order Date    9994 non-null   datetime64[ns]
#  2   Date Key      9994 non-null   object
#  3   Month         9994 non-null   object
#  4   Year          9994 non-null   object
#  5   Contact Name  9994 non-null   object
#  6   Country       9994 non-null   object
#  7   City          9994 non-null   object
#  8   Region        9994 non-null   object
#  9   Subregion     9994 non-null   object
#  10  Customer      9994 non-null   object
#  11  Customer ID   9994 non-null   object
#  12  Industry      9994 non-null   object
#  13  Segment       9994 non-null   object
#  14  Product       9994 non-null   object
#  15  License       9994 non-null   object
#  16  Sales         9994 non-null   float64
#  17  Quantity      9994 non-null   int64
# ...

# %% [markdown]
# ### **Cek Duplikasi Data**

# %%
pd.set_option('display.max_colwidth', None)

uniqueItem = []
for column in df.columns:
    uniqueItem.append([column, df[column].nunique(), df[column].unique(), df[column].dtype])

unique = pd.DataFrame(columns=['Column', 'Unique Count', 'Unique Value', 'Data Type'], data=uniqueItem)
unique
# Out:
#           Column  Unique Count  \
# 0       Order ID          5009
# 1     Order Date          1237
# 2       Date Key          1237
# 3          Month            12
# 4           Year             4
# 5   Contact Name           793
# 6        Country            48
# 7           City           262
# 8         Region             3
# 9      Subregion            12
# 10      Customer            99
# 11   Customer ID            99
# 12      Industry            10
# 13       Segment             3
# 14       Product            14
# 15       License          9994
# 16         Sales          5825
# 17      Quantity            14
# 18      Discount            12
# 19        Profit          7056
#
# ...

# %% [markdown]
# Cek duplikasi pada kolom Identifier, yang seharusnya tidak boleh ada duplikat (Order ID , License)

# %%
df['Order ID'].duplicated().sum()
# Out:
# 4985

# %%
df[df['Order ID'].duplicated(keep=False)].head()
# Out:
#            Order ID Order Date  Date Key      Month  Year   Contact Name  \
# 0  EMEA-2022-152156 2022-09-11  20221109  September  2022    Nathan Bell
# 1  EMEA-2022-152156 2022-09-11  20221109  September  2022    Nathan Bell
# 3  EMEA-2021-108966 2021-11-10  20211011   November  2021     Zoe Hodges
# 4  EMEA-2021-108966 2021-11-10  20211011   November  2021     Zoe Hodges
# 5  AMER-2020-115812 2020-09-06  20200609  September  2020  Thomas Hodges
#
#          Country           City Region Subregion           Customer  \
# 0        Ireland         Dublin   EMEA      UKIR            Chevron
# 1        Ireland         Dublin   EMEA      UKIR            Chevron
# 3        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
# 4        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
# 5  United States  New York City   AMER     NAMER        BNP Paribas
#
#   Customer ID Industry Segment                 Product     License    Sales  \
# ...

# %%
df['License'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Memperbaiki Duplikat pada kolom Order ID (Dengan menambahkan urutan item dibelakang id sebelumnya pada setiap id yang sama) <br>
# `EMEA-2022-152156` menjadi `EMEA-2022-152156-1`

# %%
# Menambahkan kolom baru untuk menghitung kemunculan setiap Order ID
df['jumlah'] = df.groupby('Order ID').cumcount() + 1

# Menggabungkan kolom Order ID dengan jumlah order id pada id yang sama untuk membentuk format yang diinginkan guna menghindari duplikat
df['Order ID'] = df['Order ID'] + '-' + df['jumlah'].astype(str)
# kolom 'jumlah' sudah tidak memiliki fungsi lagi maka kolom tersebut dapat dihapus
df = df.drop(columns='jumlah')
df.head()
# Out:
#              Order ID Order Date  Date Key      Month  Year    Contact Name  \
# 0  EMEA-2022-152156-1 2022-09-11  20221109  September  2022     Nathan Bell
# 1  EMEA-2022-152156-2 2022-09-11  20221109  September  2022     Nathan Bell
# 2  AMER-2022-138688-1 2022-06-13  20220613       June  2022  Deirdre Bailey
# 3  EMEA-2021-108966-1 2021-11-10  20211011   November  2021      Zoe Hodges
# 4  EMEA-2021-108966-2 2021-11-10  20211011   November  2021      Zoe Hodges
#
#          Country           City Region Subregion           Customer  \
# 0        Ireland         Dublin   EMEA      UKIR            Chevron
# 1        Ireland         Dublin   EMEA      UKIR            Chevron
# 2  United States  New York City   AMER     NAMER        Phillips 66
# 3        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
# 4        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
#
#   Customer ID Industry    Segment                 Product     License  \
# ...

# %%
df['Order ID'].duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#              Order ID Order Date  Date Key      Month  Year    Contact Name  \
# 0  EMEA-2022-152156-1 2022-09-11  20221109  September  2022     Nathan Bell
# 1  EMEA-2022-152156-2 2022-09-11  20221109  September  2022     Nathan Bell
# 2  AMER-2022-138688-1 2022-06-13  20220613       June  2022  Deirdre Bailey
# 3  EMEA-2021-108966-1 2021-11-10  20211011   November  2021      Zoe Hodges
# 4  EMEA-2021-108966-2 2021-11-10  20211011   November  2021      Zoe Hodges
#
#          Country           City Region Subregion           Customer  \
# 0        Ireland         Dublin   EMEA      UKIR            Chevron
# 1        Ireland         Dublin   EMEA      UKIR            Chevron
# 2  United States  New York City   AMER     NAMER        Phillips 66
# 3        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
# 4        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
#
#   Customer ID Industry    Segment                 Product     License  \
# ...

# %% [markdown]
# Mengecek apakah ada `License` yang sama pada setiap transaksi, seharusnya tidak boleh ada `License` yang sama pada setiap order karena `License` sifatnya **personal** dan **tidak boleh duplikat**

# %%
dropDupli = df.drop_duplicates(subset=['Order ID', 'License']).sort_values(by='License')
dropDupli[dropDupli.duplicated(subset='License', keep=False)]
# Out:
# Empty DataFrame
# Columns: [Order ID, Order Date, Date Key, Month, Year, Contact Name, Country, City, Region, Subregion, Customer, Customer ID, Industry, Segment, Product, License, Sales, Quantity, Discount, Profit]
# Index: []

# %% [markdown]
# Ternyata memang tidak ditemukan `License` yang duplikat sehingga dapat dikatakan `License` yang diberikan sudah personal untuk masing-masing transaksi

# %% [markdown]
# ### **Pemahaman Data (Descriptive Statistics)**

# %% [markdown]
# Menampilkan informasi dasar dari data numerik pada dataset

# %%
print('Summary Statistics : ')
print(df.describe())
# Out:
# Summary Statistics :
#                Sales     Quantity     Discount        Profit
# count    9994.000000  9994.000000  9994.000000   9994.000000
# mean     2298.580010     3.789574     0.156203    286.568959
# std      6232.451008     2.225110     0.206452   2342.601098
# min         4.440000     1.000000     0.000000 -65999.780000
# 25%       172.800000     2.000000     0.000000     17.287500
# 50%       544.900000     3.000000     0.200000     86.665000
# 75%      2099.400000     5.000000     0.200000    293.640000
# max    226384.800000    14.000000     0.800000  83999.760000

# %%
df[df['Sales']==226384.8]
# Out:
#                 Order ID Order Date  Date Key  Month  Year  Contact Name  \
# 2697  EMEA-2020-145317-2 2020-03-18  20200318  March  2020  Diane Murray
#
#       Country    City Region Subregion Customer Customer ID    Industry  \
# 2697  Germany  Berlin   EMEA   EU-WEST   Anthem        1029  Healthcare
#
#          Segment          Product     License     Sales  Quantity  Discount  \
# 2697  Enterprise  Big Ol Database  SGJPOTVE6H  226384.8         6       0.5
#
#         Profit
# 2697 -18110.78

# %%
df[df['Profit']==-65999.78]
# Out:
#                 Order ID Order Date  Date Key     Month  Year    Contact Name  \
# 7772  AMER-2022-108196-2 2022-11-26  20221126  November  2022  Faith Campbell
#
#      Country     City Region Subregion  Customer Customer ID Industry Segment  \
# 7772  Mexico  Tijuana   AMER     LATAM  Allstate        1003  Finance     SMB
#
#               Product     License     Sales  Quantity  Discount    Profit
# 7772  Big Ol Database  PM66ENV0DN  44999.85         5       0.7 -65999.78

# %% [markdown]
# Pada informasi diatas sudah tidak ditemukan value yang aneh pada dataset, hal ini terbukti pada nilai min dan max yang masih masuk akal jika didasarkan pada konteks data itu sendiri. Sehingga tidak perlu dilakukan proses lanjutan seperti `Handling Outlier`. <br>
# Hal ini didasarkan pada konteks data itu sendiri, seperti harga jual product minimum pada kolom `Sales` yaitu 4.44$ dapat dikatakan masuk akal karena selain didasarkan pada konteks data itu sendiri, seperti rentang harga di Real Life untuk product SaaS hal ini juga diperkuat dengan informasi terkait transaksi tersebut yang dilakukan untuk sebuah product dengan jumlah Quantity hanya 1 dan besaran diskon yang besar dan profit minimum pada kolom `Profit` yaitu -65999.78$ dapat dikatakan masuk akal karena transaksi tersebut dilakukan untuk product dengan jumlah user yang banyak dan disertai dengan besaran diskon yang besar. Begitu juga untuk nilai max pada 2 kolom tersebut yang masih bisa dikatakan normal.

# %%
df['Sales'].min()
# Out:
# 4.44

# %%
df['Profit'].min()
# Out:
# -65999.78

# %% [markdown]
# ### **Analyze :**

# %% [markdown]
# Tahapan Analisa data berdasarkan pada Business Task :
# 1. Menghitung besaran korelasi antar kolom
# 2. Analisa Time Series pada Dataset
# 3. Analisa Variabel yang mempengaruhi profit : <br>
#     a. Analisa pengaruh Lokasi (`Country`, `Region`, `Subregion`, `City`) perusahaan pelanggan pada `profit` dan jumlah transaksi<br>
#     b. Analisa pengaruh Latar Belakang Bisnis (`Industry`,`Segment`, `Customer`) perusahaan pelanggan pada `profit` dan jumlah transaksi<br>
#     c. Analisa pengaruh `Product` pada `Profit` dan jumlah transaksi<br>
#     d. Analisa pengaruh `diskon` pada `profit` dan jumlah transaksi<br>
# 4. Analisa tambahan penunjang

# %% [markdown]
# ### 1. Menghitung Korelasi antara kolom-kolom Numerik (`Sales` ,`Quantity`, `Discount`, `Profit`)

# %%
num_df = df[['Sales' ,'Quantity', 'Discount', 'Profit']]

korelasi = num_df.corr()
korelasi
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
plt.figure(figsize=(8, 6))

sns.heatmap(korelasi, annot=True, cmap='coolwarm', fmt=".2f")

plt.title('Heatmap Korelasi antar Kolom', fontweight='bold')
plt.show()

# %% [markdown]
# Pada Tabel korelasi diatas mengindikasikan :
# 1. Kolom `Sales` dan `Quantity` nilai korelasinya **positif** dengan besaran **0.2 (Korelasi Lemah)** artinya hubungan keduanya lemah, dengan asumsi jika nilai `Sales` meningkat maka nilai `Quantity` juga akan meningkat.
# 2. Kolom `Sales` dan `Profit` nilai korelasinya **positif** dengan besaran **0.4 (Korelasi Sedang)** artinya hubungan keduanya sedang, dengan asumsi jika nilai `Sales` meningkat maka nilai `Profit` juga akan meningkat.
# 3. Kolom `Discount` dan `Profit` nilai korelasinya **negatif** dengan besaran **0.2 (Korelasi Lemah)** artinya hubungan keduanya lemah, dengan asumsi jika nilai `Discount` meningkat maka nilai `Profit` malah akan menurun.
#
# Berdasarkan Matrix Korelasi tersebut, dapat dikatakan jika kolom pada dataset hanya kolom `Sales` dan `Profit` yang memiliki pengaruh satu sama lain setidaknya kedua kolom ini berkorelasi sedang.

# %% [markdown]
# Menghitung Pada sektor industri apa saja yang paling menguntungkan untuk perusahaan dan yang paling merugikan, sekaligus melihat product apa saja yang sering dibeli oleh Perusahaan dalam industry tersebut untuk diketahui product mana saja yang memperoleh profit terbesar dan terkecil dalam industry tersebut.

# %%
df.groupby('Industry')[['Customer']].count().sort_values(by='Customer',ascending=False).head(1)
# Out:
#           Customer
# Industry
# Finance       2127

# %% [markdown]
# ### 2. Analisa Time Series

# %% [markdown]
# Membuat sebuah copy-an dari df dan disimpan pada variabel filtered_df

# %%
filtered_df = df.copy()

# %%
filtered_df.sort_values(by='Order Date', axis=0, inplace=True)

# %%
filtered_df.head()
# Out:
#                 Order ID Order Date  Date Key    Month  Year  \
# 3365  AMER-2020-115161-1 2020-01-02  20200201  January  2020
# 157   AMER-2020-104269-1 2020-01-03  20200301  January  2020
# 8309   APJ-2020-168312-1 2020-01-03  20200301  January  2020
# 7949   APJ-2020-131009-3 2020-01-03  20200301  January  2020
# 7947   APJ-2020-131009-1 2020-01-03  20200301  January  2020
#
#            Contact Name        Country      City Region Subregion  \
# 3365          Jan White  United States   Yonkers   AMER     NAMER
# 157   Anthony Sanderson         Canada   Toronto   AMER     NAMER
# 8309      Adrian Walker          Japan     Tokyo    APJ      JAPN
# 7949    Benjamin Hughes          Japan  Shizuoka    APJ      JAPN
# 7947    Benjamin Hughes          Japan  Shizuoka    APJ      JAPN
#
#               Customer Customer ID Industry Segment                 Product  \
# 3365            Lukoil        1044   Energy     SMB         Marketing Suite
# ...

# %% [markdown]
# Mengubah kolom Order Date menjadi index pada masing-masing baris data supaya memudahkan proses analisis time-series yang dilakukan.

# %%
filtered_df = filtered_df.set_index('Order Date')

# %%
filtered_df.head()
# Out:
#                       Order ID  Date Key    Month  Year       Contact Name  \
# Order Date
# 2020-01-02  AMER-2020-115161-1  20200201  January  2020          Jan White
# 2020-01-03  AMER-2020-104269-1  20200301  January  2020  Anthony Sanderson
# 2020-01-03   APJ-2020-168312-1  20200301  January  2020      Adrian Walker
# 2020-01-03   APJ-2020-131009-3  20200301  January  2020    Benjamin Hughes
# 2020-01-03   APJ-2020-131009-1  20200301  January  2020    Benjamin Hughes
#
#                   Country      City Region Subregion          Customer  \
# Order Date
# 2020-01-02  United States   Yonkers   AMER     NAMER            Lukoil
# 2020-01-03         Canada   Toronto   AMER     NAMER  American Express
# 2020-01-03          Japan     Tokyo    APJ      JAPN            Amazon
# 2020-01-03          Japan  Shizuoka    APJ      JAPN             Apple
# 2020-01-03          Japan  Shizuoka    APJ      JAPN             Apple
#
# ...

# %% [markdown]
# Analisa Time-Series untuk total Penjualan berdasarkan Bulan

# %%
df_monthly = filtered_df.resample('M').sum()
df_monthly = df_monthly.drop(columns='Discount')
df_monthly.head(5)
# Out:
# C:\Users\bigku\AppData\Local\Temp\ipykernel_4388\516756816.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_monthly = filtered_df.resample('M').sum()
#                 Sales  Quantity    Profit
# Order Date
# 2020-01-31  284848.06       502  43431.39
# 2020-02-29  131299.30       315  28294.31
# 2020-03-31  548999.92       616    627.37
# 2020-04-30  244011.32       460  46530.31
# 2020-05-31  300427.42       565  38925.16

# %%
print(f"Nilai Sales tertinggi : {df_monthly['Sales'].max()}, Pada Tanggal : {df_monthly['Sales'].idxmax()}")
print(f"Nilai Sales terendah : {df_monthly['Sales'].min()}, Pada Tanggal : {df_monthly['Sales'].idxmin()}")
# Out:
# Nilai Sales tertinggi : 849244.66, Pada Tanggal : 2023-11-30 00:00:00
# Nilai Sales terendah : 131299.3, Pada Tanggal : 2020-02-29 00:00:00

# %%
print(f"Jumlah Quantity tertinggi : {df_monthly['Quantity'].max()}, Pada Tanggal : {df_monthly['Quantity'].idxmax()}")
print(f"Jumlah Quantity terendah : {df_monthly['Quantity'].min()}, Pada Tanggal : {df_monthly['Quantity'].idxmin()}")
# Out:
# Jumlah Quantity tertinggi : 1466, Pada Tanggal : 2023-11-30 00:00:00
# Jumlah Quantity terendah : 315, Pada Tanggal : 2020-02-29 00:00:00

# %%
print(f"Nilai Profit tertinggi : {df_monthly['Profit'].max()}, Pada Tanggal : {df_monthly['Profit'].idxmax()}")
print(f"Nilai Profit terendah : {df_monthly['Profit'].min()}, Pada Tanggal : {df_monthly['Profit'].idxmin()}")
# Out:
# Nilai Profit tertinggi : 140472.13, Pada Tanggal : 2023-03-31 00:00:00
# Nilai Profit terendah : -3363.9, Pada Tanggal : 2020-07-31 00:00:00

# %%
plt.figure(figsize=(18, 12))

plt.subplot(3,1,1)
df_monthly_sales = df_monthly[['Sales']]
plt.plot(df_monthly_sales.index, df_monthly_sales.values, marker='o', linestyle='-', color='magenta')
plt.xlabel('Month', fontsize=11, fontweight='bold')
plt.ylabel('Total Sales', fontsize=11, fontweight='bold')
plt.title('Total Sales Growth Overtime\n', fontsize=14, fontweight='bold')

plt.subplot(3,1,2)
df_monthly_quantity = df_monthly[['Quantity']]
plt.plot(df_monthly_quantity.index, df_monthly_quantity.values, marker='o', linestyle='-', color='magenta')
plt.xlabel('Month', fontsize=11, fontweight='bold')
plt.ylabel('Total Quantity', fontsize=11, fontweight='bold')
plt.title('Total Quantity Growth Overtime\n', fontsize=14, fontweight='bold')

plt.subplot(3,1,3)
df_monthly_profit = df_monthly[['Profit']]
plt.plot(df_monthly_profit.index, df_monthly_profit.values, marker='o', linestyle='-', color='magenta')
plt.xlabel('Month', fontsize=11, fontweight='bold')
plt.ylabel('Total Profit', fontsize=11, fontweight='bold')
plt.axhline(y=0, color='red')
plt.title('Total Profit Growth Overtime\n', fontsize=14, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# Pada analisis time series diatas kolom `Discount` dapat dihapus karena total discount tidak merepresentasikan apapun untuk mendukung analisa.<br>
#
# - Berdasarkan hasil analisis diatas total `Sales` tertinggi berada pada bulan **November 2023** dengan besaran nilai penjualan **849.244$** dan terendah pada Bulan **Februari 2020** dengan besaran nilai penjualan **131.299$**.<br>
# - Berdasarkan hasil analisis diatas jumlah `Quantity` tertinggi berada pada bulan **November 2023** dengan besaran total `Quantity` **1466** dan terendah pada Bulan **Februari 2020** dengan besaran total `Quantity` **315**.<br>
# - Berdasarkan hasil analisis diatas total `Profit` tertinggi berada pada bulan **Maret 2023** dengan besaran total `Profit` **140.472$** dan terendah pada Bulan **Juli 2020** dengan besaran total `Profit` **-3363$**.<br>
# - Berdasarkan LinePlot `Total Profit Growth` diketahui jika selama 4 tahun terakhir ini, perusahaan kita menemui profit loss dibawah 0 (negatif) hanya terjadi 1 kali, yaitu pada Bulan Juli 2020
#
# Berdasarkan Analisis tersebut, diketahui jika Total Sales dan Quantity yang tertinggi pada bulan November 2023 tidak menjadikan Profit tertinggi di bulan tersebut, begitu pula dengan Total Sales dan Quantity terendah pada bulan Februari 2020 tidak menjadikan bulan tersebut sebagai bulan dengan profit terendah. Hal ini membuktikan jika tinggi rendahnya Sales tidak terlalu mempengaruhi Profit secara keseluruhan.

# %% [markdown]
# Analisa Time-Series untuk total Penjualan berdasarkan Tahun

# %%
df_yearly = filtered_df.resample('Y').sum()
df_yearly = df_yearly.drop(columns='Discount')
df_yearly
# Out:
# C:\Users\bigku\AppData\Local\Temp\ipykernel_4388\2556217007.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_yearly = filtered_df.resample('Y').sum()
#                  Sales  Quantity     Profit
# Order Date
# 2020-12-31  4842474.97      7581  495439.71
# 2021-12-31  4705325.11      7979  616186.15
# 2022-12-31  6084738.31      9810  817269.44
# 2023-12-31  7339470.23     12503  935074.88

# %%
print(f"Nilai Sales tertinggi : {df_yearly['Sales'].max()}, Pada Tanggal : {df_yearly['Sales'].idxmax()}")
print(f"Nilai Sales terendah : {df_yearly['Sales'].min()}, Pada Tanggal : {df_yearly['Sales'].idxmin()}")
# Out:
# Nilai Sales tertinggi : 7339470.23, Pada Tanggal : 2023-12-31 00:00:00
# Nilai Sales terendah : 4705325.11, Pada Tanggal : 2021-12-31 00:00:00

# %%
print(f"Jumlah Quantity tertinggi : {df_yearly['Quantity'].max()}, Pada Tanggal : {df_yearly['Quantity'].idxmax()}")
print(f"Jumlah Quantity terendah : {df_yearly['Quantity'].min()}, Pada Tanggal : {df_yearly['Quantity'].idxmin()}")
# Out:
# Jumlah Quantity tertinggi : 12503, Pada Tanggal : 2023-12-31 00:00:00
# Jumlah Quantity terendah : 7581, Pada Tanggal : 2020-12-31 00:00:00

# %%
print(f"Nilai Profit tertinggi : {df_yearly['Profit'].max()}, Pada Tanggal : {df_yearly['Profit'].idxmax()}")
print(f"Nilai Profit terendah : {df_yearly['Profit'].min()}, Pada Tanggal : {df_yearly['Profit'].idxmin()}")
# Out:
# Nilai Profit tertinggi : 935074.88, Pada Tanggal : 2023-12-31 00:00:00
# Nilai Profit terendah : 495439.71, Pada Tanggal : 2020-12-31 00:00:00

# %% [markdown]
# Pada analisis time series diatas kolom `Discount` dapat dihapus karena total discount tidak merepresentasikan apapun untuk mendukung analisa.<br>
#
# Berdasarkan hasil analisis berdasarkan rentang waktu per tahun diatas :
# - Total `Sales` tertinggi berada pada Tahun **2023** dengan besaran nilai penjualan **7.339.470$** dan terendah pada Tahun **2021** dengan besaran nilai penjualan **4.705.325$**.<br>
# - Berdasarkan hasil analisis diatas jumlah `Quantity` tertinggi berada pada Tahun **2023** dengan besaran total `Quantity` **12503** dan terendah pada Tahun **2020** dengan besaran total `Quantity` **7581**.<br>
# - Berdasarkan hasil analisis diatas total `Profit` tertinggi berada pada Tahun **2023** dengan besaran total `Profit` **935.074$** dan terendah pada Tahun **2020** dengan besaran total `Profit` **495.439$**.<br>
#
# Berdasarkan Analisis tersebut, diketahui jika Total Sales, Quantity, dan Profit ketiganya memiliki nilai tertinggi pada Tahun **2023** yang menandakan Tahun ini merupakan rentang waktu paling `produktif dan profitable` bagi perusahaan, hal ini juga didukung oleh hasil analisis rentang waktu berdasarkan Bulan yang menunjukkan titik tertinggi ketiga variabel tersebut terjadi pada tahun **2023**. Untuk nilai terendah pada ketiga variabel tersebut adalah pada tahun **2020 & 2021**. Untuk nilai terendah pada `Sales` terjadi pada tahun **2021**, dan untuk Total Quantity dan Profit terendah terjadi pada tahun **2020**. Hal ini membuktikan bahwa pada tahun **2020** perusahaan kita terbilang kurang `produktif dan profitable`, hal ini juga didukung oleh analisis pada rentang waktu berdasarkan Bulan yang menunjukkan bahwa pada tahun **2020** ketiga variabel tersebut mencapai titik terendahnya.

# %% [markdown]
# ### 3. Analisa Variabel yang Mempengaruhi Profit

# %% [markdown]
# ### 1. Analisa pengaruh Lokasi Customer pada `Profit`

# %% [markdown]
# Lokasi - Profit

# %% [markdown]
# Jumlah Profit berdasarkan Region asal Customer :

# %%
Region = df.groupby('Region')['Profit'].sum().sort_values(ascending=False).head(10)
Region
# Out:
# Region
# EMEA    1474560.46
# AMER    1274269.85
# APJ      115139.87
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(14,6))
sns.barplot(x=Region.index, y=Region.values, hue=Region.index, palette='muted')
plt.title('Total Profit berdasarkan Region', fontsize=14, fontweight='bold')
plt.xlabel('Month', fontsize=11, fontweight='bold')
plt.ylabel('Total Profit', fontsize=11, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# Jumlah Profit berdasarkan Negara asal Customer :

# %%
Top10Country = df.groupby('Country')['Profit'].sum().sort_values(ascending=False).head(10)
Top10Country
# Out:
# Country
# United States     763813.98
# United Kingdom    749890.91
# Canada            334026.43
# Brazil            244631.90
# Spain             185979.53
# India             183829.38
# Finland           162500.45
# Luxembourg        108231.89
# Ireland           102491.58
# Philippines        99773.75
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(14,6))
ax=sns.barplot(x=Top10Country.index, y=Top10Country.values,  hue=Top10Country.index, palette='muted')
plt.title('Total Profit berdasarkan Country', fontsize=14, fontweight='bold')
plt.xlabel('Country', fontsize=11, fontweight='bold')
plt.ylabel('Total Profit', fontsize=11, fontweight='bold')
max = Top10Country.max()
min = Top10Country.min()

ax.axhline(max, color='black', linestyle='--')
ax.axhline(min, color='red', linestyle='--')
categories = Top10Country.index
values = Top10Country.values.round(0)
for i in range(len(categories)):
    plt.text(i, values[i], str(values[i]), ha='center', va='bottom', fontsize=9, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# Proporsi jumlah Profit berdasarkan Kota asal Customer :

# %%
Top10City = df.groupby('City')['Profit'].sum().sort_values(ascending=False).head(10)
Top10City
# Out:
# City
# London           622186.10
# New York City    303084.90
# Toronto          291768.21
# Los Angeles      175073.82
# São Paulo        139393.03
# Helsinki         119704.82
# Luxembourg       108231.89
# Mumbai           103759.15
# Manila            81940.84
# Dublin            75222.93
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(14,6))
ax = sns.barplot(x=Top10City.index, y=Top10City.values, hue=Top10City.index, palette='muted')
plt.title('Total Profit berdasarkan City', fontsize=14, fontweight='bold')
plt.xlabel('City', fontsize=11, fontweight='bold')
plt.ylabel('Total Profit', fontsize=11, fontweight='bold')

max = Top10City.max()
min = Top10City.min()

ax.axhline(max, color='black', linestyle='--')
ax.axhline(min, color='red', linestyle='--')
categories = Top10City.index
values = Top10City.values.round(0)
for i in range(len(categories)):
    plt.text(i, values[i], str(values[i]), ha='center', va='bottom', fontsize=9, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan Hasil analisa diatas, Region dengan profit tertinggi berada pada Region **EMEA / Europe, Midle-East, & Africa** diikuti oleh Region **AMER / Americas** di urutan kedua, dan Region **APJ / Asia-Pasific & Japan** di urutan terakhir. Hal ini juga didukung oleh analisa berdasarkan Negara dan Kota dimana setidaknya 40% dari Top 10 negara dan kota dengan profit tertinggi berasal dari Region **EMEA**, bahkan Profit yang didapat di Kota London mencapai 2 kali lipat dari New York City yang menempati posisi kedua pada profit tertinggi. Berdasarkan hal ini, perusahaan bisa lebih memperhatikan transaksi yang dilakukan pada Region **EMEA** ini dan menentukan target pasar ke Customer-Customer dari Region ini.

# %% [markdown]
# Lokasi - Jumlah Transaksi

# %% [markdown]
# Jumlah Transaksi berdasarkan Region asal Customer :

# %%
TransaksiReg = df.groupby('Region')['Order ID'].count().sort_values(ascending=False)
TransaksiReg
# Out:
# Region
# EMEA    4219
# AMER    3665
# APJ     2110
# Name: Order ID, dtype: int64

# %%
plt.figure(figsize=(14,6))
sns.barplot(x=TransaksiReg.index, y=TransaksiReg.values, hue=TransaksiReg.index, palette='muted' )
plt.title('Jumlah Transaksi berdasarkan Region\n', fontsize=16, fontweight='bold')
plt.xlabel('Region', fontsize=12, fontweight='bold')
plt.ylabel('Jumlah Transaksi', fontsize=11, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# Jumlah Transaksi berdasarkan Country asal Customer :

# %%
TransaksiCountry = df.groupby('Country')['Order ID'].count().sort_values(ascending=False).head(10)
TransaksiCountry
# Out:
# Country
# United States     2001
# United Kingdom    1141
# Japan              985
# France             587
# Canada             506
# Australia          492
# Mexico             469
# Germany            383
# Brazil             255
# Sweden             249
# Name: Order ID, dtype: int64

# %%
plt.figure(figsize=(14,6))
ax= sns.barplot(x=TransaksiCountry.index, y=TransaksiCountry.values, hue=TransaksiCountry.index, palette='muted' )
plt.title('Jumlah Transaksi berdasarkan Country', fontsize=14, fontweight='bold')
plt.xlabel('Country', fontsize=11, fontweight='bold')
plt.ylabel('Jumlah Transaksi', fontsize=11, fontweight='bold')

max = TransaksiCountry.max()
min = TransaksiCountry.min()

ax.axhline(max, color='black', linestyle='--')
ax.axhline(min, color='red', linestyle='--')
categories = TransaksiCountry.index
values = TransaksiCountry.values.round(0)
for i in range(len(categories)):
    plt.text(i, values[i], str(values[i]), ha='center', va='bottom', fontsize=9, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# Proporsi jumlah Transaksi berdasarkan City asal Customer :

# %%
TransaksiCity = df.groupby('City')['Order ID'].count().sort_values(ascending=False).head(10)
TransaksiCity
# Out:
# City
# London           922
# New York City    740
# Paris            537
# Los Angeles      510
# Toronto          431
# Tokyo            405
# Sydney           314
# Mexico City      193
# Seattle          170
# Aichi            162
# Name: Order ID, dtype: int64

# %%
plt.figure(figsize=(14,6))
ax = sns.barplot(x=TransaksiCity.index, y=TransaksiCity.values, hue=TransaksiCity.index, palette='muted')
plt.title('Jumlah Transaksi berdasarkan City\n', fontsize=14, fontweight='bold')
plt.xlabel('City', fontsize=11, fontweight='bold')
plt.ylabel('Jumlah Transaksi', fontsize=11, fontweight='bold')
max = TransaksiCity.max()
min = TransaksiCity.min()

ax.axhline(max, color='black', linestyle='--')
ax.axhline(min, color='red', linestyle='--')
categories = TransaksiCity.index
values = TransaksiCity.values.round(0)
for i in range(len(categories)):
    plt.text(i, values[i], str(values[i]), ha='center', va='bottom', fontsize=9, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan Hasil analisa diatas, Region dengan jumlah Transaksi tertinggi juga berada pada Region **EMEA / Europe, Midle-East, & Africa** diikuti oleh Region **AMER / Americas** di urutan kedua, dan Region **APJ / Asia-Pasific & Japan** di urutan terakhir. Meskipun pada analisa jumlah transaksi berdasarkan Negara masih dikuasai oleh US dengan total transaksi sebanyak **2001 Order** atau 2 kali lipat dari total transaksi dari UK yang menempati posisi kedua dengan jumlah transaksi terbanyak, tetapi Region **AMER** hanya menempati posisi kedua dibawah **EMEA**, dan Region **APJ** menjadi Region dengan Jumlah Transaksi terendah.<br>
#
# Berdasarkan Hal ini, menetapkan Region **EMEA** sebagai pasar utama penjualan product perusahaan kita merupakan sebuah keputusan yang tepat, mengingat Region ini selain menyumbang `Profit` tertinggi juga menjadi tempat dengan jumlah Transaksi tertinggi. Sedangkan untuk Region **APJ** kita bisa meninjau ulang penjualan product kita disana. Menentukan strategi pemasaran dan penjualan yang baru mungkin dapat meningkatkan `Profit` kita di Region **APJ**.

# %% [markdown]
# ### 2. Analisa pengaruh Background perusahaan Customer pada `Profit`

# %% [markdown]
# Proporsi Segmentasi perusahaan pelanggan pada dataset

# %%
prop = df['Segment'].value_counts()/len(df)
prop
# Out:
# SMB           0.519412
# Strategic     0.302181
# Enterprise    0.178407
# Name: Segment, dtype: float64

# %%
plt.figure(figsize=(14,6))
colors = ['#ff9999','#66b3ff','#99ff99']

plt.pie(prop.values, labels=prop.index, autopct='%1.1f%%', startangle=60, colors=colors, wedgeprops=dict(width=0.3), textprops={'color': 'black'})
plt.axis('equal')  # Agar pie plot terlihat seperti lingkaran
plt.title('Proporsi Segmentasi Pelanggan')
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.tight_layout()
# Menampilkan plot
plt.show()

# %% [markdown]
# Berdasarkan PiePlot diatas diketahui jika segmentasi pelanggan kita masih didominasi oleh segmentasi `SMB` hingga lebih dari 50% dari total keseluruhan Transaksi. Didasarkan pada hal ini, kita bisa lebih berfokus meninjau segmentasi ini.

# %% [markdown]
# Pengaruh Segmentasi perusahaan customer pada profit perusahaan kita

# %%
df.groupby(['Segment','Customer'])['Profit'].sum().sort_values(ascending=False).reset_index().head(10)
# Out:
#       Segment                Customer    Profit
# 0   Strategic               Coca-Cola  89813.24
# 1         SMB  Mondelez International  84019.18
# 2         SMB                  Anthem  81094.90
# 3         SMB           Valero Energy  65293.13
# 4         SMB                  Lukoil  64637.56
# 5         SMB                   Lowes  57715.79
# 6  Enterprise         Trafigura Group  51044.64
# 7   Strategic             Walt Disney  45715.77
# 8   Strategic                 Siemens  42603.94
# 9  Enterprise                Glencore  41093.03

# %%
Ind = df.groupby(['Industry'])['Profit'].sum().sort_values(ascending=False).head(10)
Ind
# Out:
# Industry
# Finance              503489.75
# Energy               452823.10
# Manufacturing        384131.09
# Consumer Products    370180.06
# Healthcare           319690.86
# Retail               302078.30
# Tech                 246150.45
# Communications       139763.43
# Transportation        74026.88
# Misc                  71636.26
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(14,6))

max = Ind.max()
min = Ind.min()
ax = sns.barplot(x=Ind.index, y=Ind.values, hue=Ind.index, palette='muted')
plt.title('Total Profit berdasarkan Industry', fontsize=14, fontweight='bold')
plt.xlabel('Industry', fontsize=12, fontweight='bold')
plt.ylabel('Total Profit', fontsize=12, fontweight='bold')
ax.axhline(max, color='black', linestyle='--')
ax.axhline(min, color='red', linestyle='--')
categories = Ind.index
values = Ind.values.round(0)
for i in range(len(categories)):
    plt.text(i, values[i], str(values[i]), ha='center', va='bottom', fontsize=9, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
df.groupby('Customer')['Profit'].sum().sort_values(ascending=False).reset_index().head(10)
# Out:
#                  Customer     Profit
# 0           Valero Energy  103086.26
# 1               Coca-Cola   94490.24
# 2         Trafigura Group   88678.27
# 3  Mondelez International   85776.55
# 4                   Lowes   79374.94
# 5                  Lukoil   71170.93
# 6                 Siemens   65195.09
# 7   Bank of America Corp.   64498.54
# 8                  Kroger   62561.00
# 9                  Anthem   59532.02

# %% [markdown]
# Berdasarkan hasil analisa pada Top 10 Customer berdasarkan Segmentasi dan Industri mereka dalam hal profit tertinggi diketahui jika :
#
# - Dalam hal Segmentasi masih dikuasai perusahaan-perusahaan dengan segmentasi SMB, meskipun No. 1 nya adalah `Coca-Cola` yang memiliki segmentasi Srategic, tetapi 50% dari profit tertinggi masih ditempati oleh pelanggan dengan segmentasi SMB.<br>
# - Dalam hal Industri dari perusahaan customer, posisi pertama pada Top 10 Industri yang memberi profit tertinggi pada perusahaan ditempati Industri Finance, disusul Energy di peringkat 2 dan Manufacturing di posisi 3.<br>
# - Untuk Top 10 Customer dengan profit tertinggi didominasi oleh perusahaan dengan segmentasi `SMB` dengan 6 dari 10 perusahaan berada pada segmentasi ini. sisanya ada Coca-cola dan Siemens dengan segmentasi `Strategic` dan Trafigura Group dan Kroger pada segmentasi `Enterprise`<br
#
# Berdasarkan keterangan tersebut, penentuan target pasar pada pelanggan dengan segmentasi `SMB` dan pelanggan dengan perusahaan yang bergerak di bidang `Finance`, `Energy`, dan `Manufacturing` adalah sebuah keputusan yang tepat, mengingat pelanggan dengan segmentasi dan Industri ini menyumbang profit yang tinggi pada perusahaan.<br>
# Di sisi lain kita juga harus menentukan strategi penjualan dan pemasaran yang tepat untuk menawarkan product kita ke perusahaan dengan segmentasi `Enterprise` karena minimnya transaksi yang dibuat oleh pelanggan dengan segmentasi ini.

# %% [markdown]
# ### 3. Analisa pengaruh `Product` pada `Profit`

# %% [markdown]
# Proporsi Product terjual secara keseluruhan

# %%
jumlahData = df['Product'].value_counts()
Prop_Product = df['Product'].value_counts() / len(df)

# %%
print("Jumlah data : ")
print(jumlahData)
# Out:
# Jumlah data :
# ContactMatcher                1842
# Support                       1560
# FinanceHub                     981
# SaaS Connector Pack            957
# Site Analytics                 889
# Marketing Suite - Gold         846
# ChatBot Plugin                 796
# Data Smasher                   775
# OneView                        466
# SaaS Connector Pack - Gold     254
# Marketing Suite                228
# Storage                        217
# Big Ol Database                115
# Alchemy                         68
# Name: Product, dtype: int64

# %%
plt.figure(figsize=(16, 10))
sns.barplot(x=Prop_Product.index, y=Prop_Product.values, hue=Prop_Product.index, palette='muted')
plt.title('Jumlah Transaksi per Product', fontsize=16, fontweight='bold')
plt.xticks(rotation=90, ha='center')
plt.xlabel('Product', fontsize=12, fontweight='bold')
plt.ylabel('Jumlah Transaksi', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
print("Proporsi Product : ")
print(Prop_Product)
# Out:
# Proporsi Product :
# ContactMatcher                0.184311
# Support                       0.156094
# FinanceHub                    0.098159
# SaaS Connector Pack           0.095757
# Site Analytics                0.088953
# Marketing Suite - Gold        0.084651
# ChatBot Plugin                0.079648
# Data Smasher                  0.077547
# OneView                       0.046628
# SaaS Connector Pack - Gold    0.025415
# Marketing Suite               0.022814
# Storage                       0.021713
# Big Ol Database               0.011507
# Alchemy                       0.006804
# Name: Product, dtype: float64

# %%
plt.figure(figsize=(14,6))
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99', '#c2c2f0', '#ffb3e6', '#ff6666', '#c4e7e5', '#ffcc99', '#d9b3ff', 'cyan', '#ccff99', '#ff4d4d', '#66b3ff']
explode = (0.1, 0.1, 0, 0.05, 0.05, 0.07, 0.1, 0, 0.1, 0.1, 0.2, 0.3, 0.2, 0.1)
plt.pie(Prop_Product.values, labels=Prop_Product.index, autopct='%1.1f%%', startangle=160, colors=colors, explode=explode, textprops={'color': 'black'}, wedgeprops=dict(width=0.5))
plt.axis('equal')
plt.title('Proporsi Product', fontsize=18, fontweight='bold')
plt.legend()

# Menampilkan plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan data diatas, ternyata product dengan proporsi penjualan tertinggi adalah **ContactMatcher** dengan total transaksi keseluruhan di angka **1842** dengan proporsi **18%** dan yang terendah adalah **Alchemy** dengan total transaksi keseluruhan di angka **68** dengan proporsi **kurang dari 1%**

# %% [markdown]
# Product dengan Profit tertinggi - Terendah

# %%
Product = df.groupby('Product')['Profit'].sum().sort_values(ascending=False)
Product
# Out:
# Product
# Alchemy                       556178.25
# Site Analytics                445157.23
# Data Smasher                  419366.40
# Support                       328644.60
# FinanceHub                    321364.13
# Marketing Suite - Gold        212788.22
# OneView                       181380.09
# SaaS Connector Pack           130591.62
# ContactMatcher                124962.87
# SaaS Connector Pack - Gold     69641.71
# ChatBot Plugin                 65277.85
# Big Ol Database                33847.60
# Storage                         9495.18
# Marketing Suite               -34725.57
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(14,6))
sns.barplot(x=Product.values, y=Product.index, hue=Product.index, palette='muted')
plt.title('Profit per Product\n', fontsize=17, fontweight='bold')
plt.xlabel('Total Profit', fontsize=10, fontweight='bold')
plt.ylabel('Product', fontsize=10, fontweight='bold')
plt.axvline(x=0, color='Blue')
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan hasil analisa, ternyata **Alchemy** menempati peringkat pertama sebagai product dengan total `Profit` tertinggi, meskipun secara total penjualan product tersebut menempati peringkat terakhir, ternyata secara mengejutkan **Alchemy** menjadi number 1 secara profit. Mungkin saja dengan melakukan peningkatan pada penetrasi pada product **Alchemy** ini adalah sebuah keputusan yang tepat. Sedangkan untuk product paling buruk secara `Profit` adalah **Marketing Suite** bahkan product ini menjadi satu-satunya product dengan `Profit` negatif. Product ini secara total penjualan juga memasuki peringkat yang terbilang kurang bagus yaitu pada peringkat 4 terbawah. Pada analisa selanjutnya mungkin kita harus banyak berfokus pada product **Marketing Suite** ini. Mungkin saja mempertahankan product ini **Bukan** suatu keputusan yang tepat.

# %% [markdown]
# #### Analisa Segmentasi per Product

# %%
SMB = df[df['Segment']=='SMB']
Strategic = df[df['Segment']=='Strategic']
Enterprise = df[df['Segment']=='Enterprise']

# %%
groupSMB = SMB.groupby('Product')[['Profit']].sum()
groupStrategic = Strategic.groupby('Product')[['Profit']].sum()
groupEnterprise = Enterprise.groupby('Product')[['Profit']].sum()

# %%
groupSMB.columns = [f'{col}_SMB' for col in groupSMB.columns]
groupStrategic.columns = [f'{col}_Strategic' for col in groupStrategic.columns]
groupEnterprise.columns = [f'{col}_Enterprise' for col in groupEnterprise.columns]

# %%
dfGroupSegment = pd.concat([groupStrategic, groupSMB, groupEnterprise], axis=1)
dfGroupSegment
# Out:
#                             Profit_Strategic  Profit_SMB  Profit_Enterprise
# Product
# Alchemy                            189902.80   240837.10          125438.35
# Big Ol Database                      7030.20    21410.64            5406.76
# ChatBot Plugin                      20046.44    34543.04           10688.37
# ContactMatcher                      14708.17    82675.70           27579.00
# Data Smasher                       127074.81   207359.22           84932.37
# FinanceHub                         101054.75   163113.21           57196.17
# Marketing Suite                      6384.49   -44356.40            3246.34
# Marketing Suite - Gold              91310.28    71041.94           50436.00
# OneView                             74298.94    69819.32           37261.83
# SaaS Connector Pack                 35082.16    79194.26           16315.20
# SaaS Connector Pack - Gold          25712.28    32644.10           11285.33
# ...

# %%
dfGroupSegment['Total'] = dfGroupSegment.sum(axis=1)
dfGroupSegment = dfGroupSegment.sort_values(by='Total', ascending=False)
dfGroupSegment = dfGroupSegment.drop(columns='Total')

# %%
dfGroupSegment.plot(kind='bar', stacked=True, figsize=(18, 9), colormap='Pastel2')
plt.xlabel('Products')
plt.ylabel('Profit')
plt.title('Profit by Segment for Each Product',  fontsize=18, fontweight='bold')
plt.grid(visible=True)

# Menampilkan plot
plt.legend(title='Segment')
plt.show()

# %% [markdown]
# Berdasarkan hasil analisa diatas, ditemukan jika `Alchemy` menempati peringkat pertama sebagai product dengan **Profit** tertinggi, dengan profit Utama nya didapat dari pelanggan dengan Segmentasi `SMB`. Dan `Marketing Suite` ternyata adalah **satu-satunya** Product dengan profit dibawah 0, dengan **profit loss tertinggi** disumbang dari segmentasi `SMB` juga.
#
# Berdasarkan hal ini, bisa kita simpulkan jika besarnya proporsi `SMB` bisa berdampak di dua sisi, bisa menambah profit bagi perusahaan sekaligus juga dapat menyebabkan Profit loss yang tinggi, oleh karena itu penting bagi kita untuk banyak meninjau segmentasi `SMB` ini.

# %% [markdown]
# ### **Analisa Pengaruh `Diskon` pada `Profit`**

# %% [markdown]
# ### 1. Rekomendasi Diskon untuk masing-masing product

# %%
df['Product'].nunique()
# Out:
# 14

# %%
df.groupby('Product')['Profit'].sum().sort_values(ascending=True)
# Out:
# Product
# Marketing Suite               -34725.57
# Storage                         9495.18
# Big Ol Database                33847.60
# ChatBot Plugin                 65277.85
# SaaS Connector Pack - Gold     69641.71
# ContactMatcher                124962.87
# SaaS Connector Pack           130591.62
# OneView                       181380.09
# Marketing Suite - Gold        212788.22
# FinanceHub                    321364.13
# Support                       328644.60
# Data Smasher                  419366.40
# Site Analytics                445157.23
# Alchemy                       556178.25
# Name: Profit, dtype: float64

# %% [markdown]
# a. Marketing Suite

# %%
Mark_Suite = df[df['Product']=='Marketing Suite'].groupby('Discount')['Profit'].sum().sort_values(ascending=True)
Mark_Suite
# Out:
# Discount
# 0.50   -42558.12
# 0.70   -38949.39
# 0.32   -23911.39
# 0.30    -5558.73
# 0.20     1305.01
# 0.15    14189.94
# 0.00    60757.11
# Name: Profit, dtype: float64

# %% [markdown]
# Pada hasil analisa, ditemukan jika profit terendah berada pada product Marketing Suite. Product ini menjadi **satu-satunya** product dengan profit **kurang dari 0**
#
# Pada hasil analisa terkait product tersebut ditemukan jika profit terbaik pada product Marketing Suite adalah ketika diberikan harga normal atau tanpa diskon.
# Untuk rekomendasi diskon pada product ini supaya profit menguntungkan adalah maksimal 20%.

# %% [markdown]
# b. Storage

# %%
Storage = df[df['Product']=='Storage'].groupby('Discount')['Profit'].sum().sort_values(ascending=True)
Storage
# Out:
# Discount
# 0.2    2973.13
# 0.0    6522.05
# Name: Profit, dtype: float64

# %% [markdown]
# c. ContactMatcher

# %%
ContMatcher = df[df['Product']=='ContactMatcher'].groupby('Discount')['Profit'].sum().sort_values(ascending=True)
ContMatcher
# Out:
# Discount
# 0.80   -219093.94
# 0.70   -166011.02
# 0.40   -161873.96
# 0.50    -86153.87
# 0.30    -34023.27
# 0.45    -24931.11
# 0.20    291142.51
# 0.00    525907.53
# Name: Profit, dtype: float64

# %% [markdown]
# d. ChatbotPlugin

# %%
Chatbot = df[df['Product']=='ChatBot Plugin'].groupby('Discount')['Profit'].mean().sort_values(ascending=True)
Chatbot
# Out:
# Discount
# 0.2     38.495906
# 0.0    108.044317
# Name: Profit, dtype: float64

# %% [markdown]
# e. SaaS Connector Pack

# %%
SaaS = df[df['Product']=='SaaS Connector Pack'].groupby('Discount')['Profit'].mean().sort_values(ascending=True)
SaaS
# Out:
# Discount
# 0.6   -430.772319
# 0.2     86.928750
# 0.0    295.061068
# Name: Profit, dtype: float64

# %% [markdown]
# f. Support

# %%
Support = df[df['Product']=='Support'].groupby('Discount')['Profit'].mean().sort_values(ascending=True)
Support
# Out:
# Discount
# 0.2     99.259403
# 0.0    277.698758
# Name: Profit, dtype: float64

# %% [markdown]
# g. Marketing Suite - Gold

# %%
Mark_Suite_G = df[df['Product']=='Marketing Suite - Gold'].groupby('Discount')['Profit'].mean().sort_values(ascending=True)
Mark_Suite_G
# Out:
# Discount
# 0.2   -134.473133
# 0.0    481.663642
# Name: Profit, dtype: float64

# %% [markdown]
# h. SaaS Connector Pack - Gold

# %%
SaaS_G = df[df['Product']=='SaaS Connector Pack - Gold'].groupby('Discount')['Profit'].mean().sort_values(ascending=True)
SaaS_G
# Out:
# Discount
# 0.2    194.822451
# 0.0    327.433026
# Name: Profit, dtype: float64

# %% [markdown]
# i. Big Ol Database

# %%
Big_Ol = df[df['Product']=='Big Ol Database'].groupby('Discount')['Profit'].mean().sort_values(ascending=True)
Big_Ol
# Out:
# Discount
# 0.7   -8512.747391
# 0.5   -6362.690000
# 0.4   -2051.416923
# 0.3     652.078000
# 0.2    1603.291290
# 0.1    4160.420000
# 0.0    9357.870000
# Name: Profit, dtype: float64

# %% [markdown]
# j. FinanceHub

# %%
FinanceHub = df[df['Product']=='FinanceHub'].groupby('Discount')['Profit'].mean().sort_values(ascending=True)
FinanceHub
# Out:
# Discount
# 0.3   -426.399937
# 0.2    144.195467
# 0.0    708.472957
# 0.1    935.658947
# Name: Profit, dtype: float64

# %% [markdown]
# k. OneView

# %%
Oneview = df[df['Product']=='OneView'].groupby('Discount')['Profit'].mean().sort_values(ascending=True)
Oneview
# Out:
# Discount
# 0.8   -1288.005970
# 0.2     223.020268
# 0.1     678.800625
# 0.0     855.488598
# Name: Profit, dtype: float64

# %% [markdown]
# l. Site Analytics

# %%
SiteAn = df[df['Product']=='Site Analytics'].groupby('Discount')['Profit'].mean().sort_values(ascending=True)
SiteAn
# Out:
# Discount
# 0.4    -585.851835
# 0.2     352.586354
# 0.0    1104.990611
# Name: Profit, dtype: float64

# %% [markdown]
# m. Data Smasher

# %%
Data_Smash = df[df['Product']=='Data Smasher'].groupby('Discount')['Profit'].mean().sort_values(ascending=True)
Data_Smash
# Out:
# Discount
# 0.2    218.663980
# 0.0    749.241083
# Name: Profit, dtype: float64

# %% [markdown]
# n. Alchemy

# %%
Alchemy = df[df['Product']=='Alchemy'].groupby('Discount')['Profit'].mean().sort_values(ascending=True)
Alchemy
# Out:
# Discount
# 0.4     2425.527778
# 0.2     4832.085135
# 0.0    16161.879545
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(15, 20))

plt.subplot(5,3,1)
Mark_Suite.plot(kind='barh', colormap='Accent')
plt.axvline(x=0, color='black')
plt.title('Rekomendasi Diskon Marketing Suite')

plt.subplot(5,3,2)
Storage.plot(kind='barh', colormap='Accent')
plt.title('Rekomendasi Diskon Storage')

plt.subplot(5,3,3)
Big_Ol.plot(kind='barh', colormap='Accent')
plt.axvline(x=0, color='black')
plt.title('Rekomendasi Diskon Big Ol Database')

plt.subplot(5,3,4)
Chatbot.plot(kind='barh', colormap='Accent')
plt.title('Rekomendasi Diskon Chatbot Plugin')

plt.subplot(5,3,5)
SaaS_G.plot(kind='barh', colormap='Accent')
plt.title('Rekomendasi Diskon SaaS Connector - Gold')

plt.subplot(5,3,6)
ContMatcher.plot(kind='barh', colormap='Accent')
plt.axvline(x=0, color='Black')
plt.title('Rekomendasi Diskon ContactMatcher')

plt.subplot(5,3,7)
SaaS.plot(kind='barh', colormap='Accent')
plt.axvline(x=0, color='Black')
plt.title('Rekomendasi Diskon SaaS Connector')

plt.subplot(5,3,8)
Oneview.plot(kind='barh', colormap='Accent')
plt.axvline(x=0, color='Black')
plt.title('Rekomendasi Diskon Oneview')

plt.subplot(5,3,9)
Mark_Suite_G.plot(kind='barh', colormap='Accent')
plt.axvline(x=0, color='Black')
plt.title('Rekomendasi Diskon Marketing Suite-Gold')

plt.subplot(5,3,10)
FinanceHub.plot(kind='barh', colormap='Accent')
plt.axvline(x=0, color='Black')
plt.title('Rekomendasi Diskon FinanceHub')

plt.subplot(5,3,11)
Support.plot(kind='barh', colormap='Accent')
plt.title('Rekomendasi Diskon Support')

plt.subplot(5,3,12)
Data_Smash.plot(kind='barh', colormap='Accent')
plt.title('Rekomendasi Diskon Data Smasher')

plt.subplot(5,3,13)
SiteAn.plot(kind='barh', colormap='Accent')
plt.axvline(x=0, color='Black')
plt.title('Rekomendasi Diskon Site Analysis')

plt.subplot(5,3,14)
Alchemy.plot(kind='barh', colormap='Accent')
plt.title('Rekomendasi Diskon Alchemy')


plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan Analisa tersebut, kami dapat memberikan rekomendasi diskon yang tepat yang akan memberi profit paling **optimal** berdasarkan nama Product kita, dalam hal ini kami akan membagi product kita menjadi 2 kelompok, yaitu :
#
# 1. Kelompok product aman (product dengan nilai diskon berapapun tetap mendapatkan profit positif)
# 2. Kelompok product beresiko (product yang memiliki profit negatif pada nilai diskon tertentu)
#
# Berdasarkan kelompok tersebut kami akan melakukan 2 strategi untuk menangani hal tersebut :
#
# #### 1. Kelompok product aman (`Alchemy`, `Data Smasher`, `SaaS Connector Pack - Gold`, `Support`, `ChatBot Plugin`, `Storage`)
#
# Pada kelompok ini kami akan memberikan rekomendasi besaran diskon/non-diskon untuk masing-masing product yang memberikan profit **optimal**, detailnya sebagai berikut : <br>
#
# Alchemy : Non-Diskon/Harga Normal<br>
# Data Smasher : Non-Diskon/Harga Normal<br>
# SaaS Connector Pack - Gold : Non-Diskon/Harga Normal<br>
# Support : Non-Diskon/Harga Normal<br>
# ChatBot Plugin : Non-Diskon/Harga Normal<br>
# Storage : Non-Diskon/Harga Normal<br>
#
# Note : Product diatas **bisa** berikan diskon dengan besaran yang **sama seperti sebelumnya**
#
# #### 2. Kelompok product Beresiko (`ContactMatcher`, `SaaS Connector Pack`, `Marketing Suite - Gold`, `Big Ol Database`, `FinanceHub`, `OneView`, `Site Analytics`)
#
# Pada kelompok ini kami akan memberikan rekomendasi besaran diskon/non-diskon untuk masing-masing product yang memberikan profit **optimal**, detailnya sebagai berikut : <br>
#
# Site Analytics : Non-Diskon/Harga Normal<br>
# OneView : Non-Diskon/Harga Normal<br>
# FinanceHub : Diskon 10%
# Big Ol Database : Non-Diskon/Harga Normal<br>
# Marketing Suite - Gold : Non-Diskon/Harga Normal<br>
# SaaS Connector Pack : Non-Diskon/Harga Normal<br>
# ContactMatcher : Non-Diskon/Harga Normal<br>
#
# Note : Product diatas **bisa** berikan diskon dengan besaran yang telah ditetapkan sebagai berikut :
#
# Site Analytics : Diskon maksimal 20%
# OneView : Diskon maksimal 20%
# FinanceHub : Diskon maksimal 20%
# Big Ol Database : Diskon maksimal 30%
# Marketing Suite - Gold : Diskon maksimal 10%
# SaaS Connector Pack : Diskon maksimal 20%
# ContactMatcher : Diskon maksimal 20%

# %% [markdown]
# ### **Analisa Tambahan Penunjang**

# %% [markdown]
# ### 1. Menganalisa Customer dengan Industri tertentu yang mendapat Profit Tertinggi

# %%
df[df['Industry']=='Finance'].groupby('Product')['Profit'].sum().sort_values(ascending=False).head(1)
# Out:
# Product
# Alchemy    101818.67
# Name: Profit, dtype: float64

# %%
df[(df['Industry']=='Finance') & (df['Product']=='Alchemy')].groupby('Discount')['Profit'].mean().sort_values(ascending=False)
# Out:
# Discount
# 0.0    12776.466667
# 0.2     5593.576364
# 0.4      979.965000
# Name: Profit, dtype: float64

# %% [markdown]
# Pada hasil analisa yang ditemukan, pada industri perusahaan yang memperoleh profit tertinggi yaitu industri Finance, didapati sebuah product yang memperoleh profit tertinggi yaitu Alchemy dan setelah dilihat pada kolom diskon pada industri dan product tersebut diketahui jika rata-rata profit yang didapat oleh perusahaan tertinggi adalah ketika product tersebut dijual dengan harga asli atau tanpa diskon.

# %%
df[df['Industry']=='Finance'].groupby('Product')['Profit'].sum().sort_values(ascending=True).head(1)
# Out:
# Product
# ContactMatcher   -55856.1
# Name: Profit, dtype: float64

# %%
df[(df['Industry']=='Finance') & (df['Product']=='ContactMatcher')].groupby('Discount')['Profit'].mean().sort_values(ascending=True)
# Out:
# Discount
# 0.50   -3827.080000
# 0.40   -2276.108500
# 0.45   -1408.355000
# 0.80    -903.996471
# 0.30    -608.888571
# 0.70    -592.194568
# 0.20     397.146667
# 0.00     792.094945
# Name: Profit, dtype: float64

# %% [markdown]
# Pada hasil analisa yang ditemukan, pada industri perusahaan yang memperoleh profit tertinggi yaitu industri Finance, didapati sebuah product yang memperoleh profit terendah yaitu ContactMatcher dan setelah dilihat pada kolom diskon pada industri dan product tersebut diketahui jika besaran diskon maksimal supaya perusahaan dapat memperoleh rata-rata Profit Positif adalah 20%.

# %% [markdown]
# ### 2. Menganalisa Customer dengan Industri tertentu yang mendapat Profit Terendah

# %%
df.groupby('Industry')[['Customer ID']].count().sort_values(by='Customer ID',ascending=True).head(1)
# Out:
#           Customer ID
# Industry
# Misc              107

# %%
df[df['Industry']=='Misc'].groupby('Product')['Profit'].sum().sort_values(ascending=False).head(1)
# Out:
# Product
# Alchemy    31169.47
# Name: Profit, dtype: float64

# %%
df[(df['Industry']=='Misc') & (df['Product']=='Alchemy')].groupby('Discount')['Profit'].mean().sort_values(ascending=False)
# Out:
# Discount
# 0.0    14334.76
# 0.2     2499.95
# Name: Profit, dtype: float64

# %%
df[df['Industry']=='Misc'].groupby('Product')['Profit'].sum().sort_values(ascending=True).head(1)
# Out:
# Product
# SaaS Connector Pack   -149.11
# Name: Profit, dtype: float64

# %%
diskon_product_terendah = df[(df['Industry']=='Misc') & (df['Product']=='SaaS Connector Pack')].groupby('Discount')['Profit'].mean().sort_values(ascending=True)
diskon_product_terendah
# Out:
# Discount
# 0.6    -874.8525
# 0.0     289.2000
# 0.2    1904.3000
# Name: Profit, dtype: float64

# %% [markdown]
# Pada hasil analisa yang ditemukan, pada industri perusahaan yang memperoleh profit terendah yaitu industri Lain yang tidak terklasifikasikan, didapati sebuah product yang memperoleh profit terendah yaitu SaaS Connector Pack dan setelah dilihat pada kolom diskon pada industri dan product tersebut diketahui jika Profit tertinggi adalah ketika product tersebut diberi diskon 20% dan pemberian diskon sebesar 60% akan memberatkan perusahaan dengan profit minus dengan nilai yang cukup besar.

# %% [markdown]
# ### 3. Mencari Product dengan profit < 0 terbanyak

# %%
minus = df[df['Profit'] < 0].groupby('Product')['Product'].count().sort_values(ascending=False)
minus
# Out:
# Product
# ContactMatcher            816
# FinanceHub                235
# SaaS Connector Pack       167
# Marketing Suite - Gold    161
# Site Analytics            136
# Marketing Suite           109
# Data Smasher               91
# OneView                    67
# Big Ol Database            44
# Support                    33
# Storage                    12
# Name: Product, dtype: int64

# %%
plt.figure(figsize=(18,9))
plt.grid()
ax = sns.barplot(x=minus.index, y=minus.values,hue=minus.index,palette='muted')
plt.title('Produk dengan Jumlah Transaksi Mengandung Loss Profit', fontsize=18, fontweight='bold')
plt.xlabel('Product', fontsize=13, fontweight='bold')
plt.ylabel('Jumlah Transaksi', fontsize=13, fontweight='bold')

max = minus.max()
min = minus.min()

ax.axhline(max, color='black', linestyle='--')
ax.axhline(min, color='red', linestyle='--')
categories = minus.index
values = minus.values.round(0)
for i in range(len(categories)):
    plt.text(i, values[i], str(values[i]), ha='center', va='bottom', fontsize=9, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan Hasil analisa ditemukan jika ContactMatcher adalah product yang paling banyak merugikan perusahaan dengan memiliki 816 transaksi yang menghasilkan profit negatif

# %%
ContMinus = df[(df['Profit'] < 0) & (df['Product']=='ContactMatcher')].groupby('Discount')['Profit'].mean().sort_values(ascending=True)
ContMinus
# Out:
# Discount
# 0.50   -2393.163056
# 0.45   -2266.464545
# 0.40   -2158.319467
# 0.80    -940.317339
# 0.30    -693.045600
# 0.20    -532.588387
# 0.70    -436.871105
# Name: Profit, dtype: float64

# %%
max = ContMinus.max()
ax=sns.barplot(x=ContMinus.index, y=ContMinus.values, hue=ContMinus.index, palette='muted')
plt.title('Rekomendasi Diskon Untuk Product ContactMatcher\n', fontsize=15)
ax.axhline(max, color='Blue', linestyle='--')
plt.grid(visible=True)
plt.show()

# %% [markdown]
# Berdasarkan Hasil analisa pemberian diskon yang tepat pada product ini adalah sebesar 70% Hal ini akan meminimalisir kerugian yang dialami perusahaan.

# %% [markdown]
# ### **Act :**

# %% [markdown]
# #### **Summary :**

# %% [markdown]
# 1. Besaran Diskon yang diberikan ternyata mempengaruhi Profit secara negatif, meskipun besaran pengaruhnya tidak begitu kuat (Artinya : semakin tinggi diskon yang diberikan maka profit akan menurun). <br>
#
# 2. Informasi terkait **`Lokasi`** perusahaan pelanggan ternyata juga mempengaruhi besaran profit yang kita terima, detailnya adalah sebagai berikut : <br>
# - Pelanggan dari masing-masing Region ternyata memberikan profit yang berbeda dengan Region lainnya, untuk hal ini Region **EMEA** menempati peringkat pertama untuk penghasil profit tertinggi dari pembelian product kita, disusul oleh Region **AMER** dan **APJ**, untuk Negara yang paling banyak memberi kita profit adalah USA dengan disusul UK di posisi kedua, untuk Profit berdasarkan Kota masih didominasi kota-kota dari Eropa. Begitu pula untuk jumlah Transaksi, masih didominasi oleh Region **EMEA**.
#
# 3. Latar Belakang Bisnis Pelanggan juga memberikan Total Profit yang berbeda-beda, detailnya adalah sebagai berikut :<br>
# - Profit tertinggi yang kita dapat berasal dari perusahaan-perusahaan yang memiliki segmentasi **SMB/Small-Medium Business**, disusul oleh Segmentasi **Strategic** dan terakhir **Enterprise**. Jumlah Proporsi Transaksi yang telah dibuat sebelumnya juga masih didominasi oleh Segmentasi **SMB**, hal ini berarti tanda yang bagus bagi product kita di mata perusahaan dengan segmentasi ini. Dengan tingginya permintaan pada product kita yang dilakukan oleh pelanggan dengan segmentasi ini sekaligus memberi profit yang tinggi juga untuk perusahaan. <br>
# - Perusahaan-perusahaan yang bergerak di bidang `Finance` juga memberikan profit yang tinggi pada perusahaan kita, disusul oleh perusahaan-perusahaan dari industri `Energy` dan `Manufacturing`.
# - Top 10 Customer kita dalam hal profit tertinggi didominasi oleh mereka dengan segmentasi **SMB** dan dari **Industri Finance, Energy, Manufacturing, dan ConsumerProduct**.
#
# 4. Tren Penjualan dan Profit kita cenderung meningkat selama kurun waktu 4 tahun terakhir. Rentang waktu yang memberikan signifikansi profit yang cukup ekstrim berada pada Tahun 2020 dengan menjadi Tahun dengan profit terendah selama 4 tahun terakhir dan kenaikan per Tahun paling signifikan terjadi antara 2021-2022 dengan kenaikan sampai **200.000$**, dan untuk rentang Bulan terjadi penurunan yang signifikan pada Desember 2020 - January 2021 dan kenaikan yang signifikan pada November 2022 - Desember 2022.
#
# 5. Best Product kita adalah : **Alchemy** dan Worst Product Kita adalah : **Marketing Suite**
#
# 6. 50% Product kita memberikan profit negatif jika Besaran Diskon yang diberikan tidak tepat.
#
# 7. Pemberian Diskon melebihi 50% memberikan kita kerugian yang cukup besar.

# %% [markdown]
# #### **Recommendation :**

# %% [markdown]
# 1. Pengoptimalan pemberian diskon sesuai besaran yang didasarkan pada profit yang diterima perusahaan akan sangat menguntungkan perusahaan, Pemberian diskon ini juga dapat diberikan pada pelanggan-pelanggan potensial untuk menumbuhkan *customer loyalty* pada mereka.
#
# 2. Memfokuskan target pasar kita ke pelanggan-pelanggan dari Top Region dan Top Country, dan Memberikan mereka penawaran yang didasarkan pada Profit yang kita dapatkan.
#
# 3. Melakukan penetrasi yang kuat pada penjualan product kita ke perusahaan dengan segmentasi yang potensial untuk meningkatkan profit perusahaan.
#
# 4. Memberikan penawaran diskon pada perusahaan yang bergerak di Industri Finance, Energy, dan Manufacturing pada product potensial kita yang berhubungan dengan Industri mereka.
#
# 5. Menjaga Stabilitas penjualan Product potensial kita dengan memberikan diskon yang tepat sesuai ketentuan yang didasarkan pada Profit perusahaan, dengan tujuan untuk meningkatkan Transaksi atas nama produk ini.
#
# 6. Meninjau Ulang Worst Product kita untuk selanjutnya dapat diberikan strategi marketing baru untuk meningkatkan penjualan product ini, pemberian diskon pada Product ini masih dapat dilakukan tetapi dengan ketentuan yang tepat.
#
# 7. Memberikan strategi marketing baru yang akan ditetapkan di Negara/Kota dengan Total transaksi dan Profit rendah.
#
# 8. Pada Product dengan kategori aman (secara profit berdasarkan diskon) dapat diberi diskon dengan besaran terukur.
#
# 9. Pada Product dengan kategori beresiko (secara profit berdasarkan diskon) dapat dijual dengan harga normal dalam kurun waktu tertentu.
#
# 10. Melakukan peninjauan ulang per rentang waktu tertentu untuk memastikan Strategi lama masih berhasil dan Memastikan Strategi Baru bisa diterapkan.
